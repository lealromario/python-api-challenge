# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\lealr\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\lealr\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the openweather api using key
from api_keys import weather_api_key

# Citipy dependency
from citipy import citipy

# Getting the data file (csv)
output_data = pd.read_csv(r"\Users\lealr\OneDrive\DU Bootcamp\Python APIs\API-challenge\output_data\cities.csv")
output_data
# Out:
#      Unnamed: 0           City  Latitude  Longitude  Max Temp  Humidity  \
# 0             0          Bluff  -46.6000   168.3333     50.81        71
# 1             1    Pangnirtung   66.1451   -65.7125      6.46        82
# 2             2        Rikitea  -23.1203  -134.9692     80.24        81
# 3             3           Gari   59.4307    62.3497     33.71        90
# 4             4       Coquimbo  -29.9533   -71.3436     64.13        88
# ..          ...            ...       ...        ...       ...       ...
# 540         540          Muros   42.7762    -9.0603     52.84        80
# 541         541          Yatou   37.1500   122.3833     48.83        61
# 542         542        Camargo   27.6667  -105.1667     88.75         4
# 543         543      Esmeralda   21.8525   -78.1169     83.44        50
# 544         544  Villacarrillo   38.1156    -3.0848     46.33        39
#
#            Data  Wind Speed  Cloudiness Country
# 0    1680471415        8.52          94      NZ
# 1    1680471415        3.98         100      CA
# 2    1680471415       16.04          24      PF
# 3    1680471415        0.76         100      RU
# 4    1680471416       11.50          40      CL
# ..          ...         ...         ...     ...
# 540  1680471590        7.36          81      ES
# 541  1680471590        3.76          97      CN
# 542  1680471565       18.57         100      MX
# 543  1680471591       13.89           8      CU
# 544  1680471591        3.87          12      ES
#
# [545 rows x 10 columns]

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 580

# %%
output_data.columns
# Out:
# Index(['Unnamed: 0', 'City', 'Latitude', 'Longitude', 'Max Temp', 'Humidity',
#        'Data', 'Wind Speed', 'Cloudiness', 'Country'],
#       dtype='object')

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
latitude_list = []
longitude_list = []
temp_max_list = []
humidity_list = []
wind_speed_list = []
date_list = []
country_list = []
city_list = []
cloudiness_list = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 0
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Send the API request and get the response
        response = requests.get(city_url)
        
        # Check if the response status code is OK (200)
        if response.status_code == 200:
            # Parse the JSON and retrieve data
            city_weather = response.json()

            # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
            city_lat = city_weather['coord']['lat']
            city_lng = city_weather['coord']['lon']
            city_max_temp = city_weather['main']['temp_max']
            city_humidity = city_weather['main']['humidity']
            city_clouds = city_weather['clouds']['all']
            city_wind = city_weather['wind']['speed']
            city_country = city_weather['sys']['country']
            city_date = city_weather['dt']
            city_name = city_weather['name']

            # Append the City information into city_data list
            latitude_list.append(city_lat)
            longitude_list.append(city_lng)
            temp_max_list.append(city_max_temp)
            humidity_list.append(city_humidity)
            wind_speed_list.append(city_wind)
            date_list.append(city_date)
            country_list.append(city_country)
            cloudiness_list.append(city_clouds)
            city_list.append(city_name)
        else:
            print(f"City not found. Skipping {city}...")
    
    # If an error is experienced, skip the city
    except Exception as e:
        print(f"An error occurred while processing {city}: {e}. Skipping...")
    pass
print("--------------------------------------------------------------------")
print("Data Retrieval Complete")
print("--------------------------------------------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 | busselton
# Processing Record 1 of Set 1 | vyartsilya
# Processing Record 2 of Set 1 | ilulissat
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | taltal
# Processing Record 5 of Set 1 | mutsamudu
# City not found. Skipping mutsamudu...
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | nguiu
# City not found. Skipping nguiu...
# Processing Record 11 of Set 1 | quatre cocos
# Processing Record 12 of Set 1 | constitucion
# Processing Record 13 of Set 1 | palana
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | polovinnoye
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping illoqqortoormiut...
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | galgani
# City not found. Skipping galgani...
# Processing Record 21 of Set 1 | marcona
# City not found. Skipping marcona...
# Processing Record 22 of Set 1 | victoria
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | tautira
# Processing Record 25 of Set 1 | sentyabrskiy
# City not found. Skipping sentyabrskiy...
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | boden
# Processing Record 28 of Set 1 | kendari
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | xuanhua
# Processing Record 31 of Set 1 | norman wells
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | kavaratti
# Processing Record 34 of Set 1 | prince rupert
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | ayna
# Processing Record 37 of Set 1 | chillan
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | vila velha
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | solnechnyy
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | areosa
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | marsh harbour
# Processing Record 46 of Set 1 | namibe
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | rikitea
# Processing Record 0 of Set 2 | barentsburg
# City not found. Skipping barentsburg...
# Processing Record 1 of Set 2 | kutum
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | yarada
# Processing Record 4 of Set 2 | umm lajj
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | fortuna
# Processing Record 7 of Set 2 | tighina
# Processing Record 8 of Set 2 | vodyane
# Processing Record 9 of Set 2 | turtas
# Processing Record 10 of Set 2 | attawapiskat
# City not found. Skipping attawapiskat...
# Processing Record 11 of Set 2 | labutta
# City not found. Skipping labutta...
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | chatellerault
# Processing Record 14 of Set 2 | shache
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | urumqi
# Processing Record 18 of Set 2 | lavrentiya
# Processing Record 19 of Set 2 | esperance
# Processing Record 40 of Set 3 | uruana
# Processing Record 41 of Set 3 | jamame
# Processing Record 42 of Set 3 | kununurra
# Processing Record 43 of Set 3 | sioux lookout
# Processing Record 44 of Set 3 | amga
# Processing Record 45 of Set 3 | saint george
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | sukhobuzimskoye
# Processing Record 48 of Set 3 | qaqortoq
# Processing Record 49 of Set 3 | prieska
# Processing Record 0 of Set 4 | sinnamary
# Processing Record 1 of Set 4 | khor
# Processing Record 2 of Set 4 | sao miguel do iguacu
# Processing Record 3 of Set 4 | mount gambier
# Processing Record 4 of Set 4 | novochernorechenskiy
# Processing Record 5 of Set 4 | cabo san lucas
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | lasa
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | beroroha
# Processing Record 10 of Set 4 | shitanjing
# Processing Record 11 of Set 4 | tiksi
# Processing Record 12 of Set 4 | chokurdakh
# Processing Record 13 of Set 4 | taolanaro
# City not found. Skipping taolanaro...
# Processing Record 14 of Set 4 | hirara
# Processing Record 15 of Set 4 | hay river
# Processing Record 16 of Set 4 | vardo
# Processing Record 17 of Set 4 | ossora
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | tuatapere
# Processing Record 20 of Set 4 | roald
# Processing Record 21 of Set 4 | rio grande
# Processing Record 22 of Set 4 | antalaha
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | ngunguru
# Processing Record 25 of Set 4 | shubarkuduk
# Processing Record 26 of Set 4 | fethiye
# Processing Record 27 of Set 4 | codrington
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | hopkinsville
# Processing Record 31 of Set 4 | korcula
# Processing Record 32 of Set 4 | hobyo
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | bratsk
# Processing Record 35 of Set 4 | novobirilyussy
# Processing Record 36 of Set 4 | havoysund
# Processing Record 37 of Set 4 | agirish
# Processing Record 38 of Set 4 | fort stewart
# Processing Record 39 of Set 4 | west bay
# Processing Record 40 of Set 4 | dingle
# Processing Record 41 of Set 4 | paamiut
# Processing Record 42 of Set 4 | rosiile
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | talara
# Processing Record 45 of Set 4 | bonanza
# Processing Record 46 of Set 4 | san quintin
# Processing Record 47 of Set 4 | shimoda
# Processing Record 48 of Set 4 | san andres
# Processing Record 49 of Set 4 | cape coast
# Processing Record 0 of Set 5 | kushima
# Processing Record 1 of Set 5 | monrovia
# Processing Record 2 of Set 5 | pau brasil
# Processing Record 3 of Set 5 | marsa matruh
# Processing Record 4 of Set 5 | la ronge
# Processing Record 5 of Set 5 | port alfred
# Processing Record 6 of Set 5 | palmer
# Processing Record 7 of Set 5 | lere
# Processing Record 8 of Set 5 | nhulunbuy
# Processing Record 9 of Set 5 | praia
# Processing Record 10 of Set 5 | samusu
# City not found. Skipping samusu...
# Processing Record 11 of Set 5 | inhambane
# Processing Record 12 of Set 5 | kapoeta
# Processing Record 13 of Set 5 | ust-nera
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | merauke
# Processing Record 16 of Set 5 | calama
# Processing Record 17 of Set 5 | grand gaube
# Processing Record 18 of Set 5 | bourail
# Processing Record 19 of Set 5 | margate
# Processing Record 20 of Set 5 | bredasdorp
# Processing Record 21 of Set 5 | sestri levante
# Processing Record 22 of Set 5 | amderma
# City not found. Skipping amderma...
# Processing Record 23 of Set 5 | kabinda
# Processing Record 24 of Set 5 | ribeira grande
# Processing Record 25 of Set 5 | alto araguaia
# Processing Record 26 of Set 5 | saint-philippe
# Processing Record 27 of Set 5 | alexandria
# Processing Record 28 of Set 5 | liverpool
# Processing Record 29 of Set 5 | kurilsk
# Processing Record 30 of Set 5 | olinda
# Processing Record 31 of Set 5 | da nang
# Processing Record 32 of Set 5 | toliary
# City not found. Skipping toliary...
# Processing Record 33 of Set 5 | hamilton
# Processing Record 34 of Set 5 | jalu
# Processing Record 35 of Set 5 | sao jose da coroa grande
# Processing Record 36 of Set 5 | talnakh
# Processing Record 37 of Set 5 | mys shmidta
# City not found. Skipping mys shmidta...
# Processing Record 38 of Set 5 | los llanos de aridane
# Processing Record 39 of Set 5 | nouadhibou
# Processing Record 40 of Set 5 | wollongong
# Processing Record 41 of Set 5 | agadir
# Processing Record 42 of Set 5 | faya
# Processing Record 43 of Set 5 | narsaq
# Processing Record 44 of Set 5 | alofi
# Processing Record 45 of Set 5 | mahibadhoo
# Processing Record 46 of Set 5 | phangnga
# Processing Record 47 of Set 5 | kahului
# Processing Record 48 of Set 5 | ler
# Processing Record 49 of Set 5 | oga
# Processing Record 0 of Set 6 | kidal
# Processing Record 1 of Set 6 | luzern
# Processing Record 2 of Set 6 | zhezkazgan
# Processing Record 3 of Set 6 | rocha
# Processing Record 4 of Set 6 | dibaya
# City not found. Skipping dibaya...
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | evensk
# Processing Record 7 of Set 6 | novosergiyevka
# Processing Record 8 of Set 6 | aklavik
# Processing Record 9 of Set 6 | constantine
# Processing Record 10 of Set 6 | nisia floresta
# Processing Record 11 of Set 6 | guarenas
# Processing Record 12 of Set 6 | chicama
# Processing Record 13 of Set 6 | belushya guba
# City not found. Skipping belushya guba...
# Processing Record 14 of Set 6 | conceicao da barra
# Processing Record 15 of Set 6 | brae
# Processing Record 16 of Set 6 | bilibino
# Processing Record 17 of Set 6 | tuy hoa
# Processing Record 18 of Set 6 | marabba
# Processing Record 19 of Set 6 | mayari
# City not found. Skipping mayari...
# Processing Record 20 of Set 6 | pringsewu
# Processing Record 21 of Set 6 | asau
# Processing Record 22 of Set 6 | yanam
# Processing Record 23 of Set 6 | san angelo
# Processing Record 24 of Set 6 | sayat
# Processing Record 25 of Set 6 | alugan
# Processing Record 26 of Set 6 | cidreira
# Processing Record 27 of Set 6 | pahrump
# Processing Record 28 of Set 6 | luganville
# Processing Record 29 of Set 6 | vaitupu
# City not found. Skipping vaitupu...
# Processing Record 30 of Set 6 | jibuti
# Processing Record 31 of Set 6 | kulhudhuffushi
# Processing Record 32 of Set 6 | saint-pierre
# Processing Record 33 of Set 6 | besancon
# Processing Record 34 of Set 6 | the valley
# Processing Record 35 of Set 6 | saint-joseph
# Processing Record 36 of Set 6 | kirakira
# Processing Record 37 of Set 6 | kazalinsk
# City not found. Skipping kazalinsk...
# Processing Record 38 of Set 6 | kirovskiy
# Processing Record 39 of Set 6 | kenai
# Processing Record 40 of Set 6 | geraldton
# Processing Record 41 of Set 6 | poum
# Processing Record 42 of Set 6 | lyman
# Processing Record 43 of Set 6 | dicabisagan
# Processing Record 44 of Set 6 | caravelas
# Processing Record 45 of Set 6 | cockburn town
# Processing Record 46 of Set 6 | ishigaki
# Processing Record 47 of Set 6 | sumbe
# Processing Record 48 of Set 6 | meulaboh
# Processing Record 49 of Set 6 | clyde river
# Processing Record 0 of Set 7 | srednekolymsk
# Processing Record 1 of Set 7 | goreloye
# Processing Record 2 of Set 7 | verkh-suetka
# Processing Record 3 of Set 7 | aurora
# Processing Record 4 of Set 7 | borba
# Processing Record 5 of Set 7 | harnosand
# Processing Record 6 of Set 7 | port lincoln
# Processing Record 7 of Set 7 | puerto del rosario
# Processing Record 8 of Set 7 | rakaia
# Processing Record 9 of Set 7 | esperantina
# Processing Record 10 of Set 7 | tarauaca
# Processing Record 11 of Set 7 | ulladulla
# Processing Record 12 of Set 7 | mogzon
# Processing Record 13 of Set 7 | sechura
# Processing Record 14 of Set 7 | warud
# Processing Record 15 of Set 7 | saravan
# Processing Record 16 of Set 7 | avera
# Processing Record 17 of Set 7 | hasaki
# Processing Record 18 of Set 7 | kosai
# Processing Record 19 of Set 7 | zyryanka
# Processing Record 20 of Set 7 | arraial do cabo
# Processing Record 21 of Set 7 | pangkalanbuun
# Processing Record 22 of Set 7 | port blair
# Processing Record 23 of Set 7 | suntar
# Processing Record 24 of Set 7 | talcahuano
# Processing Record 25 of Set 7 | souillac
# Processing Record 26 of Set 7 | katsuura
# Processing Record 27 of Set 7 | hami
# Processing Record 28 of Set 7 | bubaque
# Processing Record 29 of Set 7 | bam
# Processing Record 30 of Set 7 | vila franca do campo
# Processing Record 31 of Set 7 | rungata
# City not found. Skipping rungata...
# Processing Record 32 of Set 7 | coahuayana
# Processing Record 33 of Set 7 | belyy yar
# Processing Record 34 of Set 7 | dolbeau
# City not found. Skipping dolbeau...
# Processing Record 35 of Set 7 | yarmouth
# Processing Record 36 of Set 7 | port hedland
# Processing Record 37 of Set 7 | juneau
# Processing Record 38 of Set 7 | karratha
# Processing Record 39 of Set 7 | longlac
# City not found. Skipping longlac...
# Processing Record 40 of Set 7 | platanos
# Processing Record 41 of Set 7 | madang
# Processing Record 42 of Set 7 | tocache
# Processing Record 43 of Set 7 | vostok
# Processing Record 44 of Set 7 | gravdal
# Processing Record 45 of Set 7 | crestview
# Processing Record 46 of Set 7 | turki
# Processing Record 47 of Set 7 | lompoc
# Processing Record 48 of Set 7 | santa maria
# Processing Record 49 of Set 7 | sena madureira
# Processing Record 0 of Set 8 | tessalit
# Processing Record 1 of Set 8 | san luis
# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame({
    "City" : city_list,
    "Latitude" : latitude_list,
    "Longitude" : longitude_list,
    "Max Temp" : temp_max_list,
    "Humidity" : humidity_list,
    "Data" : date_list,
    "Wind Speed" : wind_speed_list,
    "Cloudiness" : cloudiness_list,
    "Country" : country_list
})

# Show the Record count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv(r"C:\Users\lealr\OneDrive\DU Bootcamp\Python APIs\API-challenge\output_data\cities.csv", index=True)

# %%
# Build scatter plot for latitude vs. temp
plt.scatter(city_data_df['Latitude'], city_data_df['Max Temp'], facecolor="orange", edgecolor="black")
plt.title("Latitude vs Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.grid()

# %%
# Latitude vs Humidity
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'], facecolor='pink', edgecolor='brown')

plt.title('Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.grid()

# %%
# Latitude vs cloudiness
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'], facecolor='pink', edgecolor='brown')

plt.title('Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.grid()

# %%
# Latitude vs wind speed
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'], facecolor='pink', edgecolor='brown')

plt.title('Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

plt.grid()

# %%
# Creating dataframes for Northern and Southern Hemispheres
north_hemisphere = city_data_df[city_data_df['Latitude'] >= 0]

south_hemisphere = city_data_df[city_data_df['Latitude'] <= 0]

# %%
north_hemisphere.head()

# %%
south_hemisphere.head()

# %%
# Linear regression on Northern Hemisphere 

# Calculate the correlation coefficient

# Pearson Correlation coefficent with SCIPY
x = north_hemisphere['Latitude']
y = north_hemisphere['Max Temp']

# Obtain m(slope) and b (intercept) of the linear regression line
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

plt.plot(x, y, 'o', color='pink')

# Adding the equation
equation_line = 'y = {:.2f}x + {:.2f}'.format(m, b)
plt.text(10, 10, equation_line, fontsize=14) 

plt.title('Northern Hemisphere Max Temp vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')


r = np.corrcoef(x, y)[0, 1]
print("The r-value is: ", r)

print('Equation of the regression line: y = {:.2f}x + {:.2f}'.format(m, b))

# %%
# Linear regression on Southern Hemisphere

x = south_hemisphere['Latitude']
y = south_hemisphere['Max Temp']

# Finding the slope and intercept
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

plt.plot(x, y, 'o', color='pink')

# Add the equation
equation_line = 'y = {:.2f}x + {:.2f}'.format(m, b)
plt.text(-50, 70, equation_line, fontsize=14)

plt.title('Southern Hemisphere Max Temp vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')

r = np.corrcoef(x, y)[0, 1]
print("The r-value is: ", r)

print('Equation of the regression line: y = {:.2f}x + {:.2f}'.format(m, b))

# %%
# Humidity Northern Hemisphere
x = north_hemisphere['Latitude']
y = north_hemisphere['Humidity']

# Finding the slope and intercept
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

plt.plot(x, y, 'o', color='pink')

# Add the equation
equation_line = 'y = {:.2f}x + {:.2f}'.format(m, b)
plt.text(50, 15, equation_line, fontsize=14)

plt.title('Northern Hemisphere Humidity vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

r = np.corrcoef(x, y)[0, 1]
print("The r-value is: ", r)

print('Equation of the regression line: y = {:.2f}x + {:.2f}'.format(m, b))

# %%
# Humidity Southern Hemisphere
x = south_hemisphere['Latitude']
y = south_hemisphere['Humidity']

# Finding the slope and intercept
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

plt.plot(x, y, 'o', color='pink')

# Add the equation
equation_line = 'y = {:.2f}x + {:.2f}'.format(m, b)
plt.text(-20, 35, equation_line, fontsize=14)

plt.title('Southern Hemisphere Humidity vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

r = np.corrcoef(x, y)[0, 1]
print("The r-value is: ", r)

print('Equation of the regression line: y = {:.2f}x + {:.2f}'.format(m, b))

# %%
# Cloudiness Northern Hemisphere
x = north_hemisphere['Latitude']
y = north_hemisphere['Cloudiness']

# Finding the slope and intercept
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

plt.plot(x, y, 'o', color='pink')

# Add the equation
equation_line = 'y = {:.2f}x + {:.2f}'.format(m, b)
plt.text(5, 58, equation_line, fontsize=14)

plt.title('Northern Hemisphere Cloudiness vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

r = np.corrcoef(x, y)[0, 1]
print("The r-value is: ", r)

print('Equation of the regression line: y = {:.2f}x + {:.2f}'.format(m, b))

# %%
# Cloudiness Southern Hemisphere
x = south_hemisphere['Latitude']
y = south_hemisphere['Cloudiness']

# Finding the slope and intercept
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

plt.plot(x, y, 'o', color='pink')

# Add the equation
equation_line = 'y = {:.2f}x + {:.2f}'.format(m, b)
plt.text(-25, 10, equation_line, fontsize=14)

plt.title('Southern Hemisphere Cloudiness vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

r = np.corrcoef(x, y)[0, 1]
print("The r-value is: ", r)

print('Equation of the regression line: y = {:.2f}x + {:.2f}'.format(m, b))

# %%
# Wind Speed Northern Hemisphere
x = north_hemisphere['Latitude']
y = north_hemisphere['Wind Speed']

# Finding the slope and intercept
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

plt.plot(x, y, 'o', color='pink')

# Add the equation
equation_line = 'y = {:.2f}x + {:.2f}'.format(m, b)
plt.text(10, 20, equation_line, fontsize=14)

plt.title('Northern Hemisphere Wind Speed vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

r = np.corrcoef(x, y)[0, 1]
print("The r-value is: ", r)

print('Equation of the regression line: y = {:.2f}x + {:.2f}'.format(m, b))

# %%
# Southern wind speed
x = south_hemisphere['Latitude']
y = south_hemisphere['Wind Speed']

# Finding the slope and intercept
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

plt.plot(x, y, 'o', color='pink')

# Add the equation
equation_line = 'y = {:.2f}x + {:.2f}'.format(m, b)
plt.text(-25, 10, equation_line, fontsize=14)

plt.title('Southern Hemisphere Wind Speed vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

r = np.corrcoef(x, y)[0, 1]
print("The r-value is: ", r)

print('Equation of the regression line: y = {:.2f}x + {:.2f}'.format(m, b))
